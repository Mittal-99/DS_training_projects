# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import cufflinks as cf
import plotly.tools as tls

# %%
df = pd.read_csv(r"C:\Users\akash\Downloads\IPL_Dataset.csv")

# %%
df
# Out:
#      POS             Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  \
# 0      1           KL Rahul   14    14   2   670  132*  55.83  518  129.34
# 1      2     Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73
# 2      3       David Warner   16    16   2   548   85*  39.14  407  134.64
# 3      4       Shreyas Iyer   17    17   2   519   88*  34.60  421  123.27
# 4      5       Ishan Kishan   14    13   4   516    99  57.33  354  145.76
# ..   ...                ...  ...   ...  ..   ...   ...    ...  ...     ...
# 128  129      Khaleel Ahmed    7     1   0     0    0*   0.00    2    0.00
# 129  130     Arshdeep Singh    8     1   0     0    0*   0.00    3    0.00
# 130  131        Daniel Sams    3     1   0     0    0*   0.00    2    0.00
# 131  132  Shreevats Goswami    2     2   0     0    0*   0.00    4    0.00
# 132  133        Trent Boult   15     1   0     0    0*   0.00    1    0.00
#
#      100  50  4s  6s
# 0      1   5  58  23
# 1      2   4  67  12
# 2      0   4  52  14
# 3      0   3  40  16
# 4      0   4  36  30
# ..   ...  ..  ..  ..
# 128    0   0   0   0
# 129    0   0   0   0
# 130    0   0   0   0
# 131    0   0   0   0
# 132    0   0   0   0
#
# [133 rows x 14 columns]

# %% [markdown]
# Q1. What is the maximum number of matches played by an individual player in a season?

# %%
df1= pd.DataFrame(df)
df1
# Out:
#      POS             Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  \
# 0      1           KL Rahul   14    14   2   670  132*  55.83  518  129.34
# 1      2     Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73
# 2      3       David Warner   16    16   2   548   85*  39.14  407  134.64
# 3      4       Shreyas Iyer   17    17   2   519   88*  34.60  421  123.27
# 4      5       Ishan Kishan   14    13   4   516    99  57.33  354  145.76
# ..   ...                ...  ...   ...  ..   ...   ...    ...  ...     ...
# 128  129      Khaleel Ahmed    7     1   0     0    0*   0.00    2    0.00
# 129  130     Arshdeep Singh    8     1   0     0    0*   0.00    3    0.00
# 130  131        Daniel Sams    3     1   0     0    0*   0.00    2    0.00
# 131  132  Shreevats Goswami    2     2   0     0    0*   0.00    4    0.00
# 132  133        Trent Boult   15     1   0     0    0*   0.00    1    0.00
#
#      100  50  4s  6s
# 0      1   5  58  23
# 1      2   4  67  12
# 2      0   4  52  14
# 3      0   3  40  16
# 4      0   4  36  30
# ..   ...  ..  ..  ..
# 128    0   0   0   0
# 129    0   0   0   0
# 130    0   0   0   0
# 131    0   0   0   0
# 132    0   0   0   0
#
# [133 rows x 14 columns]

# %%
maxclm= df.max()['Mat']
maxclm
# Out:
# 17

# %%
df2=df.sort_values('Mat',ascending=False)
df2
# Out:
#      POS          Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 3      4    Shreyas Iyer   17    17   2   519   88*  34.60  421  123.27    0
# 1      2  Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73    2
# 67    68   Kagiso Rabada   17     8   4    56   15*  14.00   49  114.28    0
# 19    20  Marcus Stoinis   17    17   3   352    65  25.14  237  148.52    0
# 114  115     T Natarajan   16     3   3     3    3*   0.00    5   60.00    0
# ..   ...             ...  ...   ...  ..   ...   ...    ...  ...     ...  ...
# 124  125  Mitchell Marsh    1     1   0     0    0*   0.00    1    0.00    0
# 97    98   Mohammad Nabi    1     1   1    11   11*   0.00    8  137.50    0
# 109  110      Andrew Tye    1     1   0     6     6   6.00    6  100.00    0
# 118  119     Nikhil Naik    1     1   0     1     1   1.00    3   33.33    0
# 98    99     Rinku Singh    1     1   0    11    11  11.00   11  100.00    0
#
#      50  4s  6s
# 3     3  40  16
# 1     4  67  12
# 67    0   4   2
# 19    3  31  16
# 114   0   0   0
# ..   ..  ..  ..
# 124   0   0   0
# 97    0   2   0
# 109   0   0   1
# 118   0   0   0
# 98    0   1   0
#
# [133 rows x 14 columns]

# %%
mxm_mat= df2.iloc[:4]
mxm_mat
# Out:
#     POS          Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 3     4    Shreyas Iyer   17    17   2   519   88*  34.60  421  123.27    0
# 1     2  Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73    2
# 67   68   Kagiso Rabada   17     8   4    56   15*  14.00   49  114.28    0
# 19   20  Marcus Stoinis   17    17   3   352    65  25.14  237  148.52    0
#
#     50  4s  6s
# 3    3  40  16
# 1    4  67  12
# 67   0   4   2
# 19   3  31  16

# %% [markdown]
# Q2. What is the highest average of a player in a season?

# %%
avg_value = df.max()['Avg']
avg_value
# Out:
# 101.0

# %% [markdown]
# Q3. What is the average number of matches played by the players in a season?

# %%
average_matches_played = df['Mat'].mean()
average_matches_played
# Out:
# 9.631578947368421

# %% [markdown]
# Q4.Please check the correlation between all the features.

# %%
df = sns.heatmap(df.corr())

# %% [markdown]
# Q5. Check the list of players who has an average greater than 50 as well strike rate above 120.

# %%
plyr_list = df[(df['Avg'] > 50) & (df['SR'] > 120)]
plyr_list
# Out:
#     POS           Player  Mat  Inns  NO  Runs    HS     Avg   BF      SR  100  \
# 0     1         KL Rahul   14    14   2   670  132*   55.83  518  129.34    1
# 4     5     Ishan Kishan   14    13   4   516    99   57.33  354  145.76    0
# 31   32   Kieron Pollard   16    12   7   268   60*   53.60  140  191.42    0
# 36   37  Wriddhiman Saha    4     4   1   214    87   71.33  153  139.86    0
# 37   38  Ruturaj Gaikwad    6     6   2   204    72   51.00  169  120.71    0
# 57   58     Deepak Hooda    7     5   4   101   62*  101.00   71  142.25    0
# 60   61       Tom Curran    5     4   3    83   54*   83.00   62  133.87    0
#
#     50  4s  6s
# 0    5  58  23
# 4    4  36  30
# 31   1  15  22
# 36   2  24   5
# 37   3  16   6
# 57   1   5   5
# 60   1   5   3

# %% [markdown]
# Q6. Please check the list of players who has an average greater than 40 and balls faced above 100.

# %%
plyr_data = df[(df['Avg'] > 40) & (df['BF'] > 100)]
plyr_data
# Out:
#     POS           Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 0     1         KL Rahul   14    14   2   670  132*  55.83  518  129.34    1
# 1     2   Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73    2
# 4     5     Ishan Kishan   14    13   4   516    99  57.33  354  145.76    0
# 8     9      Virat Kohli   15    15   4   466   90*  42.36  384  121.35    0
# 9    10   AB de Villiers   15    14   4   454   73*  45.40  286  158.74    0
# 10   11   Faf du Plessis   13    13   2   449   87*  40.81  319  140.75    0
# 14   15      Eoin Morgan   14    14   4   418   68*  41.80  302  138.41    0
# 24   25  Kane Williamson   12    11   4   317    67  45.28  237  133.75    0
# 27   28      Chris Gayle    7     7   0   288    99  41.14  210  137.14    0
# 28   29       Ben Stokes    8     8   1   285  107*  40.71  200  142.50    1
# 31   32   Kieron Pollard   16    12   7   268   60*  53.60  140  191.42    0
# 32   33    Rahul Tewatia   14    11   5   255    53  42.50  183  139.34    0
# 33   34  Ravindra Jadeja   14    11   6   232    50  46.40  135  171.85    0
# 36   37  Wriddhiman Saha    4     4   1   214    87  71.33  153  139.86    0
# 37   38  Ruturaj Gaikwad    6     6   2   204    72  51.00  169  120.71    0
#
#     50  4s  6s
# 0    5  58  23
# 1    4  67  12
# 4    4  36  30
# 8    3  23  11
# 9    5  33  23
# 10   4  42  14
# 14   1  32  24
# 24   3  26  10
# 27   3  15  23
# 28   1  36   7
# 31   1  15  22
# 32   1  13  17
# 33   1  22  11
# 36   2  24   5
# 37   3  16   6

# %% [markdown]
# Q7. Please check the list of players who scored more than 300 runs with an average greater than 45 & strike rate above 130.

# %%
data = df[(df['Runs'] > 300) & (df['Avg'] > 45) & (df['SR'] > 130)]
data
# Out:
#     POS           Player  Mat  Inns  NO  Runs   HS    Avg   BF      SR  100  \
# 4     5     Ishan Kishan   14    13   4   516   99  57.33  354  145.76    0
# 9    10   AB de Villiers   15    14   4   454  73*  45.40  286  158.74    0
# 24   25  Kane Williamson   12    11   4   317   67  45.28  237  133.75    0
#
#     50  4s  6s
# 4    4  36  30
# 9    5  33  23
# 24   3  26  10

# %% [markdown]
# Q8. Players who scroed alteast one century in this season.

# %%
century = df[df['100'] >= 1]
century
# Out:
#     POS          Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 0     1        KL Rahul   14    14   2   670  132*  55.83  518  129.34    1
# 1     2  Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73    2
# 13   14  Mayank Agarwal   11    11   0   424   106  38.54  271  156.45    1
# 28   29      Ben Stokes    8     8   1   285  107*  40.71  200  142.50    1
#
#     50  4s  6s
# 0    5  58  23
# 1    4  67  12
# 13   2  44  15
# 28   1  36   7

# %% [markdown]
# Q9. Players who scored atleast 4 half centuries in this season.

# %%
half_century= df[df['50']>=4]
half_century
# Out:
#     POS            Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 0     1          KL Rahul   14    14   2   670  132*  55.83  518  129.34    1
# 1     2    Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73    2
# 2     3      David Warner   16    16   2   548   85*  39.14  407  134.64    0
# 4     5      Ishan Kishan   14    13   4   516    99  57.33  354  145.76    0
# 5     6   Quinton de Kock   16    16   2   503   78*  35.92  358  140.50    0
# 6     7  Suryakumar Yadav   16    15   3   480   79*  40.00  331  145.01    0
# 7     8  Devdutt Padikkal   15    15   0   473    74  31.53  379  124.80    0
# 9    10    AB de Villiers   15    14   4   454   73*  45.40  286  158.74    0
# 10   11    Faf du Plessis   13    13   2   449   87*  40.81  319  140.75    0
#
#     50  4s  6s
# 0    5  58  23
# 1    4  67  12
# 2    4  52  14
# 4    4  36  30
# 5    4  46  22
# 6    4  61  11
# 7    5  51   8
# 9    5  33  23
# 10   4  42  14

# %% [markdown]
# Q10. Check the list of players who hit more than 45 boundARIES and more than 10 sixes in this season.

# %%
list_of_plyr= df[(df['4s'] > 45) & (df['6s'] > 10)]
list_of_plyr
# Out:
#    POS            Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 0    1          KL Rahul   14    14   2   670  132*  55.83  518  129.34    1
# 1    2    Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73    2
# 2    3      David Warner   16    16   2   548   85*  39.14  407  134.64    0
# 5    6   Quinton de Kock   16    16   2   503   78*  35.92  358  140.50    0
# 6    7  Suryakumar Yadav   16    15   3   480   79*  40.00  331  145.01    0
#
#    50  4s  6s
# 0   5  58  23
# 1   4  67  12
# 2   4  52  14
# 5   4  46  22
# 6   4  61  11

# %% [markdown]
# Q11. Plot a histogram of number of matches played in a season by players.

# %%
df1= sns.histplot(df['Mat'])
df1.set_title('num of matches')
# Out:
# Text(0.5, 1.0, 'num of matches')

# %% [markdown]
# Q12. Plot the histogram of balls faced by players.

# %%
df2 = sns.histplot(df['BF'])

# %% [markdown]
# Q13. Top 20 players with most runs in a season.

# %%
most_run = df.sort_values('Runs',ascending=False)
most_run
# Out:
#      POS             Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  \
# 0      1           KL Rahul   14    14   2   670  132*  55.83  518  129.34
# 1      2     Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73
# 2      3       David Warner   16    16   2   548   85*  39.14  407  134.64
# 3      4       Shreyas Iyer   17    17   2   519   88*  34.60  421  123.27
# 4      5       Ishan Kishan   14    13   4   516    99  57.33  354  145.76
# ..   ...                ...  ...   ...  ..   ...   ...    ...  ...     ...
# 128  129      Khaleel Ahmed    7     1   0     0    0*   0.00    2    0.00
# 129  130     Arshdeep Singh    8     1   0     0    0*   0.00    3    0.00
# 130  131        Daniel Sams    3     1   0     0    0*   0.00    2    0.00
# 131  132  Shreevats Goswami    2     2   0     0    0*   0.00    4    0.00
# 132  133        Trent Boult   15     1   0     0    0*   0.00    1    0.00
#
#      100  50  4s  6s
# 0      1   5  58  23
# 1      2   4  67  12
# 2      0   4  52  14
# 3      0   3  40  16
# 4      0   4  36  30
# ..   ...  ..  ..  ..
# 128    0   0   0   0
# 129    0   0   0   0
# 130    0   0   0   0
# 131    0   0   0   0
# 132    0   0   0   0
#
# [133 rows x 14 columns]

# %%
most_run.head(20)
# Out:
#     POS            Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 0     1          KL Rahul   14    14   2   670  132*  55.83  518  129.34    1
# 1     2    Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73    2
# 2     3      David Warner   16    16   2   548   85*  39.14  407  134.64    0
# 3     4      Shreyas Iyer   17    17   2   519   88*  34.60  421  123.27    0
# 4     5      Ishan Kishan   14    13   4   516    99  57.33  354  145.76    0
# 5     6   Quinton de Kock   16    16   2   503   78*  35.92  358  140.50    0
# 6     7  Suryakumar Yadav   16    15   3   480   79*  40.00  331  145.01    0
# 7     8  Devdutt Padikkal   15    15   0   473    74  31.53  379  124.80    0
# 8     9       Virat Kohli   15    15   4   466   90*  42.36  384  121.35    0
# 9    10    AB de Villiers   15    14   4   454   73*  45.40  286  158.74    0
# 10   11    Faf du Plessis   13    13   2   449   87*  40.81  319  140.75    0
# 11   12      Shubman Gill   14    14   1   440   70*  33.84  373  117.96    0
# 12   13     Manish Pandey   16    15   2   425   83*  32.69  333  127.62    0
# 13   14    Mayank Agarwal   11    11   0   424   106  38.54  271  156.45    1
# 14   15       Eoin Morgan   14    14   4   418   68*  41.80  302  138.41    0
# 15   16      Sanju Samson   14    14   1   375    85  28.84  236  158.89    0
# 16   17     Ambati Rayudu   12    11   2   359    71  39.88  282  127.30    0
# 17   18   Nicholas Pooran   14    14   4   353    77  35.30  208  169.71    0
# 18   19       Nitish Rana   14    14   0   352    87  25.14  254  138.58    0
# 19   20    Marcus Stoinis   17    17   3   352    65  25.14  237  148.52    0
#
#     50  4s  6s
# 0    5  58  23
# 1    4  67  12
# 2    4  52  14
# 3    3  40  16
# 4    4  36  30
# 5    4  46  22
# 6    4  61  11
# 7    5  51   8
# 8    3  23  11
# 9    5  33  23
# 10   4  42  14
# 11   3  44   9
# 12   3  35  18
# 13   2  44  15
# 14   1  32  24
# 15   3  21  26
# 16   1  30  12
# 17   2  23  25
# 18   3  43  12
# 19   3  31  16

# %%
df=most_run[:20]
x=df['Runs']
y=df['Player']
plt.bar(x,y)
plt.show()

# %% [markdown]
# Q14. Bar chart for top 20 players with best strike rate in a season.

# %%
top_plyr= df.sort_values('SR',ascending=False)
top_plyr
# Out:
#      POS             Player  Mat  Inns  NO  Runs   HS    Avg   BF      SR  \
# 31    32     Kieron Pollard   16    12   7   268  60*  53.60  140  191.42
# 50    51       Jofra Archer   14    10   4   113  27*  18.83   63  179.36
# 29    30      Hardik Pandya   14    13   5   281  60*  35.12  157  178.98
# 83    84   Tushar Deshpande    5     2   1    21  20*  21.00   12  175.00
# 33    34    Ravindra Jadeja   14    11   6   232   50  46.40  135  171.85
# ..   ...                ...  ...   ...  ..   ...  ...    ...  ...     ...
# 128  129      Khaleel Ahmed    7     1   0     0   0*   0.00    2    0.00
# 129  130     Arshdeep Singh    8     1   0     0   0*   0.00    3    0.00
# 130  131        Daniel Sams    3     1   0     0   0*   0.00    2    0.00
# 131  132  Shreevats Goswami    2     2   0     0   0*   0.00    4    0.00
# 132  133        Trent Boult   15     1   0     0   0*   0.00    1    0.00
#
#      100  50  4s  6s
# 31     0   1  15  22
# 50     0   0   5  10
# 29     0   1  14  25
# 83     0   0   2   1
# 33     0   1  22  11
# ..   ...  ..  ..  ..
# 128    0   0   0   0
# 129    0   0   0   0
# 130    0   0   0   0
# 131    0   0   0   0
# 132    0   0   0   0
#
# [133 rows x 14 columns]

# %%
top_plyr.head(20)
# Out:
#      POS               Player  Mat  Inns  NO  Runs   HS    Avg   BF      SR  \
# 31    32       Kieron Pollard   16    12   7   268  60*  53.60  140  191.42
# 50    51         Jofra Archer   14    10   4   113  27*  18.83   63  179.36
# 29    30        Hardik Pandya   14    13   5   281  60*  35.12  157  178.98
# 83    84     Tushar Deshpande    5     2   1    21  20*  21.00   12  175.00
# 33    34      Ravindra Jadeja   14    11   6   232   50  46.40  135  171.85
# 53    54          Abdul Samad   12     8   3   111   33  22.20   65  170.76
# 17    18      Nicholas Pooran   14    14   4   353   77  35.30  208  169.71
# 81    82  Nathan Coulter-Nile    7     2   1    25  24*  25.00   15  166.66
# 110  111       Jasprit Bumrah   15     1   1     5   5*   0.00    3  166.66
# 74    75         Chris Morris    9     5   1    34  25*   8.50   21  161.90
# 15    16         Sanju Samson   14    14   1   375   85  28.84  236  158.89
# 9     10       AB de Villiers   15    14   4   454  73*  45.40  286  158.74
# 13    14       Mayank Agarwal   11    11   0   424  106  38.54  271  156.45
# 69    70   Krishnappa Gowtham    2     2   1    42  22*  42.00   27  155.55
# 113  114      Dhawal Kulkarni    1     1   1     3   3*   0.00    2  150.00
# 19    20       Marcus Stoinis   17    17   3   352   65  25.14  237  148.52
# 68    69      Lockie Ferguson    5     2   2    43  24*   0.00   29  148.27
# 41    42      Shimron Hetmyer   12    11   3   185   45  23.12  125  148.00
# 4      5         Ishan Kishan   14    13   4   516   99  57.33  354  145.76
# 6      7     Suryakumar Yadav   16    15   3   480  79*  40.00  331  145.01
#
#      100  50  4s  6s
# 31     0   1  15  22
# 50     0   0   5  10
# 29     0   1  14  25
# 83     0   0   2   1
# 33     0   1  22  11
# 53     0   0   8   6
# 17     0   2  23  25
# 81     0   0   4   0
# 110    0   0   0   0
# 74     0   0   2   3
# 15     0   3  21  26
# 9      0   5  33  23
# 13     1   2  44  15
# 69     0   0   3   2
# 113    0   0   0   0
# 19     0   3  31  16
# 68     0   0   4   1
# 41     0   0  11  12
# 4      0   4  36  30
# 6      0   4  61  11

# %%
df= top_plyr[:20]
x=df['SR']
y=df['Player']
plt.bar(x,y)
plt.show()

# %% [markdown]
# Q15. Top 30 players with highest number of sixes.

# %%
plyr= df.sort_values('6s',ascending=False)
plyr
# Out:
#      POS               Player  Mat  Inns  NO  Runs   HS    Avg   BF      SR  \
# 4      5         Ishan Kishan   14    13   4   516   99  57.33  354  145.76
# 15    16         Sanju Samson   14    14   1   375   85  28.84  236  158.89
# 29    30        Hardik Pandya   14    13   5   281  60*  35.12  157  178.98
# 17    18      Nicholas Pooran   14    14   4   353   77  35.30  208  169.71
# 14    15          Eoin Morgan   14    14   4   418  68*  41.80  302  138.41
# ..   ...                  ...  ...   ...  ..   ...  ...    ...  ...     ...
# 98    99          Rinku Singh    1     1   0    11   11  11.00   11  100.00
# 99   100          Shivam Mavi    8     3   1    10    9   5.00   14   71.42
# 100  101  Varun Chakaravarthy   13     3   1    10   7*   5.00   15   66.66
# 101  102       Jaydev Unadkat    7     1   0     9    9   9.00   13   69.23
# 132  133          Trent Boult   15     1   0     0   0*   0.00    1    0.00
#
#      100  50  4s  6s
# 4      0   4  36  30
# 15     0   3  21  26
# 29     0   1  14  25
# 17     0   2  23  25
# 14     0   1  32  24
# ..   ...  ..  ..  ..
# 98     0   0   1   0
# 99     0   0   1   0
# 100    0   0   0   0
# 101    0   0   0   0
# 132    0   0   0   0
#
# [133 rows x 14 columns]

# %%
df=plyr[:30]
x=df['6s']
y=df['Player']
plt.bar(x,y)
plt.show()

# %% [markdown]
# Q16. Scatter plot of runs scored by a player v/s balls faced in a season.

# %%
df1 = sns.scatterplot(x='Runs',y='BF', data=df)
df1.set_title('run scored')
# Out:
# Text(0.5, 1.0, 'run scored')

# %% [markdown]
# Q17. KDE plot for averages on a season.

# %%
sns.kdeplot(df['Avg'])
# Out:
# <AxesSubplot:xlabel='Avg', ylabel='Density'>
